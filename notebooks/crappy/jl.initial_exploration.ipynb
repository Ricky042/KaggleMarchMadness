# %% [markdown]
# # Initial Exploration into the MM25 Data

# %%
import polars as pl


cities = pl.read_csv("../data/landing/march-machine-learning-mania-2025/Cities.csv")
display(cities)
# Out:
# shape: (503, 3)
# ┌────────┬──────────────┬───────┐
# │ CityID ┆ City         ┆ State │
# │ ---    ┆ ---          ┆ ---   │
# │ i64    ┆ str          ┆ str   │
# ╞════════╪══════════════╪═══════╡
# │ 4001   ┆ Abilene      ┆ TX    │
# │ 4002   ┆ Akron        ┆ OH    │
# │ 4003   ┆ Albany       ┆ NY    │
# │ 4004   ┆ Albuquerque  ┆ NM    │
# │ 4005   ┆ Allentown    ┆ PA    │
# │ …      ┆ …            ┆ …     │
# │ 4521   ┆ Westwego     ┆ LA    │
# │ 4522   ┆ Frankfort    ┆ KY    │
# │ 4523   ┆ Rockford     ┆ IL    │
# │ 4524   ┆ Collierville ┆ TN    │
# │ 4525   ┆ College Park ┆ GA    │
# └────────┴──────────────┴───────┘
